# %% [markdown]
# <a href="https://colab.research.google.com/github/Hruday-p/hruday/blob/main/Pune_Housing_value_Predictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("/content/pune_house_prices.csv")
data
# Out:
#            id              area  square_feet  num_bedrooms  num_bathrooms  \
# 0           1       Viman Nagar         1521             1              1
# 1           2     Kalyani Nagar         2957             1              2
# 2           3  Pimpri-Chinchwad         2816             3              2
# 3           4     Kalyani Nagar         2869             3              1
# 4           5     Kalyani Nagar         1285             3              3
# ...       ...               ...          ...           ...            ...
# 99995   99996         Hinjewadi         2629             3              1
# 99996   99997     Koregaon Park         1025             5              1
# 99997   99998     Kalyani Nagar         1177             2              1
# 99998   99999       Viman Nagar         2386             3              3
# 99999  100000     Koregaon Park         3061             5              3
#
#        year_built  has_garage     price
# ...

# %%
data.head(5)
# Out:
#    id              area  square_feet  num_bedrooms  num_bathrooms  year_built  \
# 0   1       Viman Nagar         1521             1              1        2016
# 1   2     Kalyani Nagar         2957             1              2        2003
# 2   3  Pimpri-Chinchwad         2816             3              2        1993
# 3   4     Kalyani Nagar         2869             3              1        2000
# 4   5     Kalyani Nagar         1285             3              3        2012
#
#    has_garage     price
# 0           0   4315847
# 1           1  12861115
# 2           0   8615274
# 3           1   5360008
# 4           0   6412778

# %%
data.tail(5)
# Out:
#            id           area  square_feet  num_bedrooms  num_bathrooms  \
# 99995   99996      Hinjewadi         2629             3              1
# 99996   99997  Koregaon Park         1025             5              1
# 99997   99998  Kalyani Nagar         1177             2              1
# 99998   99999    Viman Nagar         2386             3              3
# 99999  100000  Koregaon Park         3061             5              3
#
#        year_built  has_garage     price
# 99995        2007           0  10925108
# 99996        1993           0   3385039
# 99997        2015           0   7647345
# 99998        1985           1   8468781
# 99999        1984           1  13697913

# %%
data['has_garage'].value_counts()
# Out:
# has_garage
# 1    50073
# 0    49927
# Name: count, dtype: int64

# %%
sns.countplot(x='has_garage',data=data)
# Out:
# <Axes: xlabel='has_garage', ylabel='count'>

# %%
data['year_built'].value_counts()
# Out:
# year_built
# 1998    2401
# 1994    2378
# 2021    2339
# 2001    2337
# 2016    2335
# 1995    2335
# 2015    2330
# 1986    2327
# 1981    2310
# 2020    2308
# 2010    2305
# 2014    2298
# 2012    2297
# 1989    2293
# 2004    2288
# 2013    2286
# 1993    2284
# 2003    2282
# 2008    2281
# 2000    2277
# 2005    2274
# 2007    2273
# 1980    2269
# 1996    2268
# 1992    2264
# 2002    2259
# 2017    2258
# 1985    2254
# 1990    2253
# 1982    2252
# 1983    2252
# 1988    2241
# 2023    2236
# 2011    2235
# 2019    2235
# 1999    2231
# 2018    2229
# 1991    2224
# 1987    2222
# 2006    2221
# 2009    2206
# 2022    2196
# 1997    2191
# 1984    2166
# Name: count, dtype: int64

# %%
sns.countplot(x='year_built', data=data)
# Out:
# <Axes: xlabel='year_built', ylabel='count'>

# %%
data['area'].value_counts()
# Out:
# area
# Kalyani Nagar       20187
# Hinjewadi           20082
# Koregaon Park       20018
# Viman Nagar         19981
# Pimpri-Chinchwad    19732
# Name: count, dtype: int64

# %%
data['num_bathrooms'].value_counts()
# Out:
# num_bathrooms
# 1    33453
# 3    33407
# 2    33140
# Name: count, dtype: int64

# %%
data['num_bedrooms'].value_counts()
# Out:
# num_bedrooms
# 1    20111
# 3    20051
# 5    20010
# 2    19944
# 4    19884
# Name: count, dtype: int64

# %%
least_year=data['year_built'].min()
print(least_year)
# Out:
# 1980

# %%
latest_year=data['year_built'].max()
print(latest_year)
# Out:
# 2023

# %%
data['square_feet'].value_counts()
# Out:
# square_feet
# 3437    58
# 2821    56
# 1838    56
# 2302    56
# 1888    55
#         ..
# 2828    21
# 1478    20
# 3196    20
# 2596    20
# 894     19
# Name: count, Length: 2700, dtype: int64

# %%
least_sqfeet=data['square_feet'].min()
print(least_sqfeet)
# Out:
# 800

# %%
max_sqfeet=data['square_feet'].max()
print(max_sqfeet)
# Out:
# 3499

# %%
bathrooms = data['num_bathrooms'].value_counts()

# %%
plt.pie(bathrooms, labels=bathrooms.index, startangle=90, autopct='%1.1f%%')
plt.title('Number of Bathrooms')
plt.axis('equal')
plt.show()

# %%
missing_values = data.isnull().sum()
print("Missing values per column:")
print(missing_values)
# Out:
# Missing values per column:
# id               0
# area             0
# square_feet      0
# num_bedrooms     0
# num_bathrooms    0
# year_built       0
# has_garage       0
# price            0
# dtype: int64

# %%
plt.boxplot(data['price'])
plt.title('Price Boxplot')
plt.ylabel('Price')
plt.show()

# %%
data
# Out:
#            id              area  square_feet  num_bedrooms  num_bathrooms  \
# 0           1       Viman Nagar         1521             1              1
# 1           2     Kalyani Nagar         2957             1              2
# 2           3  Pimpri-Chinchwad         2816             3              2
# 3           4     Kalyani Nagar         2869             3              1
# 4           5     Kalyani Nagar         1285             3              3
# ...       ...               ...          ...           ...            ...
# 99995   99996         Hinjewadi         2629             3              1
# 99996   99997     Koregaon Park         1025             5              1
# 99997   99998     Kalyani Nagar         1177             2              1
# 99998   99999       Viman Nagar         2386             3              3
# 99999  100000     Koregaon Park         3061             5              3
#
#        year_built  has_garage     price
# ...

# %%
data['area'].value_counts()
# Out:
# area
# Kalyani Nagar       20187
# Hinjewadi           20082
# Koregaon Park       20018
# Viman Nagar         19981
# Pimpri-Chinchwad    19732
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
data['area']=le.fit_transform(data['area'])
data
# Out:
#            id  area  square_feet  num_bedrooms  num_bathrooms  year_built  \
# 0           1     4         1521             1              1        2016
# 1           2     1         2957             1              2        2003
# 2           3     3         2816             3              2        1993
# 3           4     1         2869             3              1        2000
# 4           5     1         1285             3              3        2012
# ...       ...   ...          ...           ...            ...         ...
# 99995   99996     0         2629             3              1        2007
# 99996   99997     2         1025             5              1        1993
# 99997   99998     1         1177             2              1        2015
# 99998   99999     4         2386             3              3        1985
# 99999  100000     2         3061             5              3        1984
#
#        has_garage     price
# 0               0   4315847
# ...

# %%
data['area'].value_counts()
# Out:
# area
# 1    20187
# 0    20082
# 2    20018
# 4    19981
# 3    19732
# Name: count, dtype: int64

# %% [markdown]
# Training the Model

# %%
x = data.drop('price', axis=1)
y=data['price']
print(x)
print(y)
# Out:
#            id  area  square_feet  num_bedrooms  num_bathrooms  year_built  \
# 0           1     4         1521             1              1        2016
# 1           2     1         2957             1              2        2003
# 2           3     3         2816             3              2        1993
# 3           4     1         2869             3              1        2000
# 4           5     1         1285             3              3        2012
# ...       ...   ...          ...           ...            ...         ...
# 99995   99996     0         2629             3              1        2007
# 99996   99997     2         1025             5              1        1993
# 99997   99998     1         1177             2              1        2015
# 99998   99999     4         2386             3              3        1985
# 99999  100000     2         3061             5              3        1984
#
#        has_garage
# 0               0
# 1               1
# 2               0
# ...

# %%
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_absolute_error, accuracy_score

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=70)

# %%
models={
    "LinearRegression": LinearRegression(),
    "RandomForestRegressor": RandomForestRegressor(),
    "GradientBoostingClassifier": GradientBoostingClassifier(),
    "KNeighborsRegressor": KNeighborsRegressor()
}

# %%
results = {}

for name, model in models.items():
    # Train the model
    model.fit(x_train, y_train)

    # Make predictions on the test data
    y_pred = model.predict(x_test)

    # Evaluate the model using Mean Absolute Error
    mae = mean_absolute_error(y_test, y_pred)

    # Store the results
    results[name] = mae

# Print the results
print("Model performance (Mean Absolute Error):")
for name, mae in results.items():
    print(f"{name}: {mae}")
